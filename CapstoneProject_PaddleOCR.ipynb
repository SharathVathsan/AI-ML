# %%
# !pip install --upgrade pip
# !pip install "paddlepaddle-gpu>=2.3"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.9/584.9 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 78.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 46.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.11.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# ...

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 256521, done.
# remote: Counting objects: 100% (655/655), done.
# remote: Compressing objects: 100% (391/391), done.
# remote: Total 256521 (delta 340), reused 495 (delta 258), pack-reused 255866
# Receiving objects: 100% (256521/256521), 415.48 MiB | 36.67 MiB/s, done.
# Resolving deltas: 100% (209162/209162), done.

# %%
# !pip install -r PaddleDetection/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 50.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 23.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 69.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.5/210.5 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 100.3 MB/s eta 0:00:00
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1302 sha256=d9ec614cbd639d556abd5adc05416d0e59aa60486735faad762b96a353b9eac7
# ...

# %%
# !cd PaddleDetection/pretrained_model
# !wget https://paddleocr.bj.bcebos.com/ppstructure/models/layout/picodet_lcnet_x1_0_fgd_layout.pdparams
# !wget https://paddleocr.bj.bcebos.com/ppstructure/models/layout/picodet_lcnet_x1_0_fgd_layout_infer.tar
# Out:
# --2023-06-09 06:39:03--  https://paddleocr.bj.bcebos.com/ppstructure/models/layout/picodet_lcnet_x1_0_fgd_layout.pdparams
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7320743 (7.0M) [application/octet-stream]
# Saving to: ‘picodet_lcnet_x1_0_fgd_layout.pdparams’
#
# picodet_lcnet_x1_0_ 100%[===================>]   6.98M  1.65MB/s    in 16s
#
# 2023-06-09 06:39:20 (458 KB/s) - ‘picodet_lcnet_x1_0_fgd_layout.pdparams’ saved [7320743/7320743]
#
# --2023-06-09 06:39:20--  https://paddleocr.bj.bcebos.com/ppstructure/models/layout/picodet_lcnet_x1_0_fgd_layout_infer.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1002:0:ff:b001:368a
# ...

# %%
# !tar -xvf /content/picodet_lcnet_x1_0_fgd_layout_infer.tar
# Out:
# picodet_lcnet_x1_0_fgd_layout_infer/
# picodet_lcnet_x1_0_fgd_layout_infer/model.pdmodel
# picodet_lcnet_x1_0_fgd_layout_infer/model.pdiparams.info
# picodet_lcnet_x1_0_fgd_layout_infer/infer_cfg.yml
# picodet_lcnet_x1_0_fgd_layout_infer/model.pdiparams

# %%
import torch

# %%
model = torch.load(R'/content/picodet_lcnet_x1_0_fgd_layout_infer')
model
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-12-83437d1cb0c4> in <cell line: 1>()
# ----> 1 model = torch.load(R'/content/picodet_lcnet_x1_0_fgd_layout_infer')
#       2 model
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789         pickle_load_args['encoding'] = 'utf-8'
#     790
# --> 791     with _open_file_like(f, 'rb') as opened_file:
#     792         if _is_zipfile(opened_file):
#     793             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
# ...

# %%
# !pip install sparrow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 11.3 MB/s eta 0:00:00
# ...
#   Created wheel for sparrow: filename=sparrow-1.0b4-py3-none-any.whl size=66233 sha256=8b95fdeac7dfbb234f044df56ab300c337152b3750d5156e98caa0dbb277b082
#   Stored in directory: /root/.cache/pip/wheels/d4/94/5a/1377f09c7c4e5ae0227339b1554825cf7029ace29fc8b42646
# Successfully built sparrow
# ...

# %%
# !git clone 'https://github.com/katanaml/sparrow.git'
# Out:
# Cloning into 'sparrow'...
# remote: Enumerating objects: 13536, done.
# remote: Counting objects: 100% (2460/2460), done.
# remote: Compressing objects: 100% (1094/1094), done.
# remote: Total 13536 (delta 1352), reused 2436 (delta 1344), pack-reused 11076
# Receiving objects: 100% (13536/13536), 791.52 MiB | 18.21 MiB/s, done.
# Resolving deltas: 100% (8481/8481), done.
# Updating files: 100% (13347/13347), done.

# %%
# !cd '/content/sparrow'

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !ls
# Out:
# sample_data  sparrow

# %%
cd sparrow/sparrow-ui/
# Out:
# /content/sparrow/sparrow-ui

# %%
# !ls
# Out:
# assets	   Dockerfile	main.py		  toolbar	views
# config	   docs		README.MD	  toolbar_main
# config.py  favicon.ico	requirements.txt  tools

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 47.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.2/799.2 kB 40.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.4/518.4 kB 50.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 74.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 20.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 104.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.6 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# 2023-06-17 12:59:50.340
# ...
#   command:
#
#     streamlit run main.py [ARGUMENTS]
# 2023-06-17 12:59:50.341 Session state does not function when running a script without `streamlit run`

# %%
# !streamlit run main.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:7860
#   External URL: http://34.141.170.209:7860
#
#   Stopping...
# ^C

# %%
docker build --tag katanaml/sparrow-ui .
# Out:
# /bin/bash: docker: command not found

# %%
import tools

# %%
# !ls
# Out:
# assets	   Dockerfile	main.py      requirements.txt  tools
# config	   docs		__pycache__  toolbar	       views
# config.py  favicon.ico	README.MD    toolbar_main

# %%
# !cd '/content/sparrow'
!
# Out:
# /bin/bash: cwd: command not found

# %%
# !ls
# Out:
# assets	   Dockerfile	main.py      requirements.txt  tools
# config	   docs		__pycache__  toolbar	       views
# config.py  favicon.ico	README.MD    toolbar_main

# %%
# Out:
# /content/sparrow/sparrow-ui

# %%
from sparrow_data import tools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-bad2ae834e0f> in <cell line: 1>()
# ----> 1 from sparrow_data import tools
#
# ModuleNotFoundError: No module named 'sparrow_data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tools.pdf_converter import PDFConverter
from tools.ocr_extractor import OCRExtractor
import os
import shutil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-5f0883047f7a> in <cell line: 1>()
# ----> 1 from tools.pdf_converter import PDFConverter
#       2 from tools.ocr_extractor import OCRExtractor
#       3 import os
#       4 import shutil
#
# ModuleNotFoundError: No module named 'tools.pdf_converter'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tools.pdf_converter import PDFConverter
from tools.ocr_extractor import OCRExtractor
import os
import shutil


def main():
    # Convert pdf to jpg
    pdf_converter = PDFConverter()
    pdf_converter.convert_to_jpg('docs/input/invoices/Dataset with valid information',
                                 'docs/input/invoices/processed/images')

    # define the source and destination directory
    src_dir = 'docs/input/invoices/processed/images'
    dst_dir = '../sparrow-ui/docs/images'

    # Get list of files in source directory
    files = os.listdir(src_dir)

    # Loop through all files in source directory and copy to destination directory
    for f in files:
        src_file = os.path.join(src_dir, f)
        dst_file = os.path.join(dst_dir, f)
        shutil.copy(src_file, dst_file)


    # OCR
    ocr_extractor = OCRExtractor('db_resnet50', 'crnn_vgg16_bn', pretrained=True)
    ocr_extractor.extract('docs/input/invoices/processed', show_prediction=False)

if _name_ == '_main_':
    main()
